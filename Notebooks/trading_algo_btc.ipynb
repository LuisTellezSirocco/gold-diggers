# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import sqlite3
from datetime import datetime
import ccxt
from typing import Dict, List, Tuple


class ScalpingStrategy:
    def __init__(self, initial_capital: float = 50.0, commission_rate: float = 0.001):
        self.capital = initial_capital
        self.commission_rate = commission_rate
        self.position_size = 0
        self.in_position = False
        self.trades_db = "trades.db"
        self.setup_database()
        # Parámetros de Supertrain
        self.atr_period = 10
        self.atr_multiplier = 3
        # Parámetros de Estocástico
        self.stoch_length = 7
        self.stoch_smoothk = 3
        self.stoch_smoothd = 3

    def setup_database(self):
        conn = sqlite3.connect(self.trades_db)
        c = conn.cursor()
        c.execute("""CREATE TABLE IF NOT EXISTS trades
                    (timestamp TEXT, symbol TEXT, action TEXT, 
                     price REAL, quantity REAL, commission REAL,
                     profit_loss REAL, running_capital REAL)""")
        conn.commit()
        conn.close()

    def log_trade(self, symbol: str, action: str, price: float, quantity: float, 
                  commission: float, profit_loss: float):
        """Registra las operaciones en la base de datos"""
        conn = sqlite3.connect(self.trades_db)
        c = conn.cursor()
        
        timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        
        c.execute("""INSERT INTO trades 
                     (timestamp, symbol, action, price, quantity, commission, 
                      profit_loss, running_capital)
                     VALUES (?, ?, ?, ?, ?, ?, ?, ?)""",
                  (timestamp, symbol, action, price, quantity, commission, 
                   profit_loss, self.capital))
        
        conn.commit()
        conn.close()
        
    def analyze_results(self) -> Dict:
        conn = sqlite3.connect(self.trades_db)
        df_trades = pd.read_sql_query("SELECT * FROM trades", conn)
        conn.close()

        if len(df_trades) == 0:
            return {
                "total_trades": 0,
                "profitable_trades": 0,
                "losing_trades": 0,
                "total_profit": 0,
                "max_profit": 0,
                "max_loss": 0,
                "final_capital": self.capital,
                "return_pct": 0,
            }

        results = {
            "total_trades": len(df_trades),
            "profitable_trades": len(df_trades[df_trades["profit_loss"] > 0]),
            "losing_trades": len(df_trades[df_trades["profit_loss"] <= 0]),
            "total_profit": df_trades["profit_loss"].sum(),
            "max_profit": df_trades["profit_loss"].max(),
            "max_loss": df_trades["profit_loss"].min(),
            "final_capital": self.capital,
            "return_pct": ((self.capital - 50) / 50) * 100,
            "win_rate": len(df_trades[df_trades["profit_loss"] > 0])
            / len(df_trades)
            * 100,
        }

        print("\n📊 Resumen del Backtest:")
        print(f"Total operaciones: {results['total_trades']}")
        print(f"Operaciones ganadoras: {results['profitable_trades']}")
        print(f"Operaciones perdedoras: {results['losing_trades']}")
        print(f"Win rate: {results['win_rate']:.2f}%")
        print(f"Beneficio total: {results['total_profit']:.2f} USDT")
        print(f"Máximo beneficio: {results['max_profit']:.2f} USDT")
        print(f"Máxima pérdida: {results['max_loss']:.2f} USDT")
        print(f"Capital final: {results['final_capital']:.2f} USDT")
        print(f"Retorno: {results['return_pct']:.2f}%")

        return results

    def calculate_indicators(self, df: pd.DataFrame) -> pd.DataFrame:
        # Cálculo del Supertrain (usando ATR como base)
        df["atr"] = ta.atr(df["high"], df["low"], df["close"], length=self.atr_period)
        df["supertrain_upper"] = df["close"] + (df["atr"] * self.atr_multiplier)
        df["supertrain_lower"] = df["close"] - (df["atr"] * self.atr_multiplier)
        
        # Cálculo del Estocástico
        stoch = ta.stoch(df["high"], df["low"], df["close"], 
                        k=self.stoch_length, 
                        d=self.stoch_smoothk, 
                        smooth_k=self.stoch_smoothd)
        df["stoch_k"] = stoch["STOCHk_7_3_3"]
        df["stoch_d"] = stoch["STOCHd_7_3_3"]
        
        # Determinar tendencia con Supertrain
        df["trend"] = "neutral"
        df.loc[df["close"] > df["supertrain_upper"], "trend"] = "bullish"
        df.loc[df["close"] < df["supertrain_lower"], "trend"] = "bearish"
        
        return df

    def identify_market_condition(self, row: pd.Series) -> str:
        """Identifica el estado actual del mercado basado en Supertrain y Estocástico"""
        
        # Determinar tendencia usando Supertrain
        trend = row["trend"]
        
        # Determinar condición del estocástico
        stoch_condition = "neutral"
        if row["stoch_k"] > 80:
            stoch_condition = "overbought"
        elif row["stoch_k"] < 20:
            stoch_condition = "oversold"
            
        # Determinar momentum basado en el cruce del estocástico
        momentum = "neutral"
        if row["stoch_k"] > row["stoch_d"]:
            momentum = "bullish"
        elif row["stoch_k"] < row["stoch_d"]:
            momentum = "bearish"
        
        return f"{trend}_{stoch_condition}_{momentum}"


    def get_signal(self, row: pd.Series) -> Tuple[str, float, float]:
        """
        Genera señales basadas en Supertrain y Estocástico
        Returns: (signal, stop_loss, take_profit)
        """
        signal = "HOLD"
        stop_loss = 0.0
        take_profit = 0.0

        # Zonas de sobrecompra/sobreventa
        overbought_level = 80
        oversold_level = 20

        # Señales de compra
        if row["trend"] == "bullish" and not self.in_position:
            # Cruce alcista en zona de sobreventa
            if (row["stoch_k"] > row["stoch_d"] and 
                row["stoch_k"] < oversold_level):
                signal = "BUY"
                stop_loss = row["supertrain_lower"]
                # Take profit con ratio 1:2
                risk = row["close"] - stop_loss
                take_profit = row["close"] + (risk * 2)

        # Señales de venta
        elif row["trend"] == "bearish" and not self.in_position:
            # Cruce bajista en zona de sobrecompra
            if (row["stoch_k"] < row["stoch_d"] and 
                row["stoch_k"] > overbought_level):
                signal = "SELL"
                stop_loss = row["supertrain_upper"]
                # Take profit con ratio 1:2
                risk = stop_loss - row["close"]
                take_profit = row["close"] - (risk * 2)

        return signal, stop_loss, take_profit

    def calculate_position_size(self, price: float, stop_loss: float) -> float:
        """Calcula el tamaño de la posición con gestión de riesgo estricta"""
        risk_per_trade = self.capital * 0.01  # 1% riesgo máximo por operación
        risk_per_unit = price - stop_loss

        if risk_per_unit <= 0:
            return 0

        position_size = risk_per_trade / risk_per_unit
        max_position = (self.capital * 0.95) / price  # Máximo 95% del capital
        return min(position_size, max_position)

    def execute_backtest(self, df: pd.DataFrame, symbol: str = "BTC/USDT"):
        df = self.calculate_indicators(df)
        trades = []
        self.entry_price = 0
        self.stop_loss_price = 0
        self.take_profit_price = 0
        consecutive_losses = 0
        max_consecutive_losses = 3

        print(f"🚀 Iniciando backtest con capital inicial: {self.capital} USDT")

        for index, row in df.iterrows():
            if consecutive_losses >= max_consecutive_losses:
                print("⚠️ Máximo de pérdidas consecutivas alcanzado. Deteniendo trading.")
                break

            signal, stop_loss, take_profit = self.get_signal(row)

            if signal == "BUY" and not self.in_position:
                self.position_size = self.calculate_position_size(row["close"], stop_loss)
                if self.position_size > 0:
                    commission = row["close"] * self.position_size * self.commission_rate
                    if commission + (row["close"] * self.position_size) <= self.capital:
                        self.entry_price = row["close"]
                        self.stop_loss_price = stop_loss
                        self.take_profit_price = take_profit
                        self.capital -= row["close"] * self.position_size + commission
                        self.in_position = True
                        self.log_trade(
                            symbol,
                            "BUY",
                            row["close"],
                            self.position_size,
                            commission,
                            0,
                        )
                        print(
                            f"🔵 COMPRA: Precio={row['close']:.2f} | "
                            f"Cantidad={self.position_size:.6f} | "
                            f"Capital={self.capital:.2f}"
                        )

            elif signal == "SELL" and self.in_position:
                commission = row["close"] * self.position_size * self.commission_rate
                profit_loss = (row["close"] - self.entry_price) * self.position_size - commission
                self.capital += row["close"] * self.position_size - commission
                self.log_trade(
                    symbol,
                    "SELL",
                    row["close"],
                    self.position_size,
                    commission,
                    profit_loss,
                )

                if profit_loss < 0:
                    consecutive_losses += 1
                else:
                    consecutive_losses = 0

                print(
                    f"🔴 VENTA: Precio={row['close']:.2f} | "
                    f"P/L={profit_loss:.2f} | Capital={self.capital:.2f}"
                )
                self.in_position = False
                self.position_size = 0

        return self.analyze_results()


# Ejemplo de uso
if __name__ == "__main__":
    exchange = ccxt.binance({"enableRateLimit": True})

    ohlcv = exchange.fetch_ohlcv("BTC/USDT", "5m", limit=5000)
    df = pd.DataFrame(
        ohlcv, columns=["timestamp", "open", "high", "low", "close", "volume"]
    )
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms")
    df.set_index("timestamp", inplace=True)

    strategy = ScalpingStrategy(initial_capital=50.0)
    results = strategy.execute_backtest(df)
# Out:
# 🚀 Iniciando backtest con capital inicial: 50.0 USDT

# %%
# Ejemplo de uso
if __name__ == "__main__":
    # Obtener datos históricos
    exchange = ccxt.binance({"enableRateLimit": True})

    # Obtenemos más datos históricos para mejor análisis
    ohlcv = exchange.fetch_ohlcv("BTC/USDT", "5m", limit=1000)
    df = pd.DataFrame(
        ohlcv, columns=["timestamp", "open", "high", "low", "close", "volume"]
    )
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms")
    df.set_index("timestamp", inplace=True)

    # Ejecutar estrategia
    strategy = ScalpingStrategy(initial_capital=50.0)
    results = strategy.execute_backtest(df)

# %%
# Ejemplo de uso
if __name__ == "__main__":
    # Obtener datos históricos (ejemplo con ccxt)
    exchange = ccxt.binance({"enableRateLimit": True})

    ohlcv = exchange.fetch_ohlcv("BTC/USDT", "5m", limit=500)
    df = pd.DataFrame(
        ohlcv, columns=["timestamp", "open", "high", "low", "close", "volume"]
    )
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms")
    df.set_index("timestamp", inplace=True)

# %%
from pygold.download import descargar_datos_yahoo

# %%
df = descargar_datos_yahoo(
    ticker="BTC-USD", inicio="2024-11-01", fin="2024-11-09", intervalo="1m"
)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                                    open          high           low  \
# time
# 2024-11-01 00:00:00+00:00  70202.875000  70202.875000  70202.875000
# 2024-11-01 00:01:00+00:00  70208.898438  70208.898438  70208.898438
# 2024-11-01 00:03:00+00:00  70223.117188  70223.117188  70223.117188
# 2024-11-01 00:04:00+00:00  70241.531250  70241.531250  70241.531250
# 2024-11-01 00:05:00+00:00  70245.648438  70245.648438  70245.648438
# ...                                 ...           ...           ...
# 2024-11-08 23:52:00+00:00  76533.835938  76533.835938  76533.835938
# 2024-11-08 23:53:00+00:00  76540.476562  76540.476562  76540.476562
# 2024-11-08 23:54:00+00:00  76544.757812  76544.757812  76544.757812
# 2024-11-08 23:55:00+00:00  76518.382812  76518.382812  76518.382812
# 2024-11-08 23:57:00+00:00  76527.921875  76527.921875  76527.921875
#
#                                   close     adj close    volume
# time
# 2024-11-01 00:00:00+00:00  70202.875000  70202.875000         0
# 2024-11-01 00:01:00+00:00  70208.898438  70208.898438  12374016
# 2024-11-01 00:03:00+00:00  70223.117188  70223.117188  46391296
# 2024-11-01 00:04:00+00:00  70241.531250  70241.531250         0
# 2024-11-01 00:05:00+00:00  70245.648438  70245.648438         0
# ...                                 ...           ...       ...
# 2024-11-08 23:52:00+00:00  76533.835938  76533.835938         0
# 2024-11-08 23:53:00+00:00  76540.476562  76540.476562         0
# 2024-11-08 23:54:00+00:00  76544.757812  76544.757812   3166208
# 2024-11-08 23:55:00+00:00  76518.382812  76518.382812         0
# 2024-11-08 23:57:00+00:00  76527.921875  76527.921875   2064384
#
# [9049 rows x 6 columns]

# %%
df = (
    df.reset_index()
    .rename(
        columns=dict(
            zip(
                ["time", "open", "high", "low", "close", "volume"],
                ["timestamp", "open", "high", "low", "close", "volume"],
            )
        )
    )
    .set_index("timestamp")
)

# %%
# Ejecutar estrategia
strategy = ScalpingStrategy(initial_capital=50.0)
results = strategy.execute_backtest(df)
# Out:
# 🚀 Iniciando backtest con capital inicial: 50.0 USDT
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70202.88
# ❌ No hay señal de compra - 0/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70208.90
# ❌ No hay señal de compra - 0/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70223.12
# ❌ No hay señal de compra - 0/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70241.53
# ❌ No hay señal de compra - 0/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70245.65
# ❌ No hay señal de compra - 0/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70324.89
# ❌ No hay señal de compra - 0/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70311.42
# ❌ No hay señal de compra - 0/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70321.46
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70303.61
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70287.69
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70271.28
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70285.53
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70320.24
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70347.69
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70330.34
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70307.04
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70321.45
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70355.22
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70362.11
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70331.06
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70322.87
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70316.32
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70302.45
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70301.48
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70308.34
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70290.95
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: False
# Precio actual: 70348.99
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70321.88
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70328.09
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70318.39
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70316.14
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70285.71
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70264.32
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70179.90
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70147.18
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70130.82
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70115.59
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70100.91
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70100.71
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70117.78
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70193.41
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70173.08
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70154.62
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70150.47
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70153.16
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: True
# Precio actual: 70207.47
# ✅ Señal de compra generada - 4/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006979314433694065 BTC/USDT @ 70207.46875 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=70207.47 | Cantidad=0.000698 | Capital=0.95
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006979314433694065 BTC/USDT @ 70150.71875 | P/L: -0.09 USDT
# 🔴 VENTA: Precio=70150.72 | P/L=-0.09 | Capital=49.86
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70116.70
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70090.02
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70085.57
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70080.95
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70106.20
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70122.18
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70120.89
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70139.81
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: True
# Precio actual: 70154.75
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006965342098465782 BTC/USDT @ 70154.75 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=70154.75 | Cantidad=0.000697 | Capital=0.95
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006965342098465782 BTC/USDT @ 70112.640625 | P/L: -0.08 USDT
# 🔴 VENTA: Precio=70112.64 | P/L=-0.08 | Capital=49.74
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70076.60
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 70016.74
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69986.06
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69984.68
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69946.74
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69957.52
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69953.84
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69943.16
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69946.93
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69868.52
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69649.02
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69552.21
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69642.73
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69622.45
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69760.17
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69791.77
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69749.05
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69736.44
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69690.41
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: True
# Precio actual: 69748.02
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006988111690098284 BTC/USDT @ 69748.015625 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=69748.02 | Cantidad=0.000699 | Capital=0.95
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006988111690098284 BTC/USDT @ 69403.390625 | P/L: -0.29 USDT
# 🔴 VENTA: Precio=69403.39 | P/L=-0.29 | Capital=49.40
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69564.77
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69583.62
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69513.30
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69525.93
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69470.32
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69330.91
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69322.90
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69303.79
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69301.26
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69384.84
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69358.51
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69048.97
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69132.53
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69086.16
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69039.50
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 68979.53
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 68926.41
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 68801.54
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 68913.94
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 68838.73
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 68951.74
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: True
# Precio actual: 69043.23
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0007011459672242638 BTC/USDT @ 69043.234375 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=69043.23 | Cantidad=0.000701 | Capital=0.94
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0007011459672242638 BTC/USDT @ 69194.09375 | P/L: 0.06 USDT
# 🔴 VENTA: Precio=69194.09 | P/L=0.06 | Capital=49.41
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69191.73
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69172.35
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69167.16
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69165.80
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69271.64
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69282.86
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69277.86
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: True
# Precio actual: 69341.95
# ✅ Señal de compra generada - 4/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006982505692937264 BTC/USDT @ 69341.953125 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=69341.95 | Cantidad=0.000698 | Capital=0.94
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: True
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006982505692937264 BTC/USDT @ 69546.0 | P/L: 0.09 USDT
# 🔴 VENTA: Precio=69546.00 | P/L=0.09 | Capital=49.45
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: False
# Precio actual: 69544.74
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006968556361028361 BTC/USDT @ 69544.7421875 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=69544.74 | Cantidad=0.000697 | Capital=0.94
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006968556361028361 BTC/USDT @ 69550.734375 | P/L: -0.04 USDT
# 🔴 VENTA: Precio=69550.73 | P/L=-0.04 | Capital=49.36
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69540.73
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69545.20
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69549.59
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69505.30
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69460.24
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69479.13
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69463.74
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69401.05
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69404.92
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69390.20
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69386.11
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69383.69
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69372.91
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69356.02
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69348.17
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69329.27
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69327.41
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69305.11
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69302.27
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69265.70
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69261.97
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69313.91
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69307.66
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69296.40
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69294.36
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69284.23
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 69269.28
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: True
# RSI favorable: True
# Precio actual: 69274.07
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: True
# RSI favorable: True
# Precio actual: 69258.80
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: False
# MACD favorable: True
# RSI favorable: True
# Precio actual: 69269.66
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006983106892132456 BTC/USDT @ 69269.6640625 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=69269.66 | Cantidad=0.000698 | Capital=0.94
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006983106892132456 BTC/USDT @ 69342.6640625 | P/L: 0.00 USDT
# 🔴 VENTA: Precio=69342.66 | P/L=0.00 | Capital=49.31
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: True
# RSI favorable: True
# Precio actual: 69318.00
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: True
# RSI favorable: True
# Precio actual: 69307.16
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: True
# RSI favorable: True
# Precio actual: 69322.84
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: False
# Precio actual: 69406.37
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006962883576405594 BTC/USDT @ 69406.3671875 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=69406.37 | Cantidad=0.000696 | Capital=0.94
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006962883576405594 BTC/USDT @ 69417.40625 | P/L: -0.04 USDT
# 🔴 VENTA: Precio=69417.41 | P/L=-0.04 | Capital=49.22
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: False
# Precio actual: 69445.91
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006946363366437016 BTC/USDT @ 69445.90625 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=69445.91 | Cantidad=0.000695 | Capital=0.94
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: True
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006946363366437016 BTC/USDT @ 69523.9453125 | P/L: 0.01 USDT
# 🔴 VENTA: Precio=69523.95 | P/L=0.01 | Capital=49.18
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: False
# Precio actual: 69521.38
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006932856501630012 BTC/USDT @ 69521.375 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=69521.38 | Cantidad=0.000693 | Capital=0.94
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: True
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006932856501630012 BTC/USDT @ 69542.3828125 | P/L: -0.03 USDT
# 🔴 VENTA: Precio=69542.38 | P/L=-0.03 | Capital=49.10
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: False
# Precio actual: 69547.07
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006918761910162995 BTC/USDT @ 69547.0703125 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=69547.07 | Cantidad=0.000692 | Capital=0.93
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: True
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006918761910162995 BTC/USDT @ 69533.9609375 | P/L: -0.06 USDT
# 🔴 VENTA: Precio=69533.96 | P/L=-0.06 | Capital=48.99
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: False
# Precio actual: 69530.84
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0006905536295738067 BTC/USDT @ 69530.8359375 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=69530.84 | Cantidad=0.000691 | Capital=0.93
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0006905536295738067 BTC/USDT @ 69506.609375 | P/L: -0.06 USDT
# 🔴 VENTA: Precio=69506.61 | P/L=-0.06 | Capital=48.88
#
# 🔍 Análisis de entrada:
# ...
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76499.86
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76489.09
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: True
# Precio actual: 76504.24
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0001437035266243691 BTC/USDT @ 76504.2421875 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=76504.24 | Cantidad=0.000144 | Capital=0.21
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0001437035266243691 BTC/USDT @ 76492.7265625 | P/L: -0.01 USDT
# 🔴 VENTA: Precio=76492.73 | P/L=-0.01 | Capital=11.19
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76492.22
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76522.11
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76489.21
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76475.48
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76517.74
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76576.95
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: True
# Precio actual: 76569.05
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0001432793081976171 BTC/USDT @ 76569.0546875 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=76569.05 | Cantidad=0.000143 | Capital=0.21
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0001432793081976171 BTC/USDT @ 76552.6484375 | P/L: -0.01 USDT
# 🔴 VENTA: Precio=76552.65 | P/L=-0.01 | Capital=11.17
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76558.89
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76528.16
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76533.96
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76501.14
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76526.74
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76547.58
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76472.52
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76456.15
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76455.73
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76458.88
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76476.81
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76461.52
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76452.40
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76401.13
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76413.49
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76410.09
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76384.38
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76408.70
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76436.02
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76432.45
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76379.11
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76424.20
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: True
# Precio actual: 76430.95
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0001432267661916926 BTC/USDT @ 76430.9453125 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=76430.95 | Cantidad=0.000143 | Capital=0.21
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.0001432267661916926 BTC/USDT @ 76451.296875 | P/L: -0.01 USDT
# 🔴 VENTA: Precio=76451.30 | P/L=-0.01 | Capital=11.15
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: True
# RSI favorable: True
# Precio actual: 76444.59
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76442.27
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: True
# RSI favorable: True
# Precio actual: 76465.00
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.00014291969963021133 BTC/USDT @ 76465.0 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=76465.00 | Cantidad=0.000143 | Capital=0.21
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: True
# Tendencia reversa: True
# RSI sobrecomprado: False
# ✅ Señal de venta generada
# 💾 Trade registrado: SELL 0.00014291969963021133 BTC/USDT @ 76412.796875 | P/L: -0.02 USDT
# 🔴 VENTA: Precio=76412.80 | P/L=-0.02 | Capital=11.12
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76400.05
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76396.15
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: False
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76391.71
# ❌ No hay señal de compra - 1/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: False
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76426.44
# ❌ No hay señal de compra - 2/4 condiciones cumplidas
#
# 🔍 Análisis de entrada:
# Momentum positivo: True
# Tendencia alineada: True
# MACD favorable: False
# RSI favorable: True
# Precio actual: 76485.73
# ✅ Señal de compra generada - 3/4 condiciones cumplidas
# 💾 Trade registrado: BUY 0.0001425054099252732 BTC/USDT @ 76485.734375 | P/L: 0.00 USDT
# 🔵 COMPRA: Precio=76485.73 | Cantidad=0.000143 | Capital=0.21
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: True
# RSI sobrecomprado: False
#
# 🔍 Análisis de salida:
# Take profit alcanzado: False
# Momentum negativo: False
# Tendencia reversa: False
# RSI sobrecomprado: False
#
# 📊 Resumen del Backtest:
# Total operaciones: 2642
# Operaciones ganadoras: 408
# Operaciones perdedoras: 2234
# Beneficio total: -25.58 USDT
# Máximo beneficio: 1.11 USDT
# Máxima pérdida: -1.15 USDT
# Capital final: 0.21 USDT
# Retorno: -99.58%
